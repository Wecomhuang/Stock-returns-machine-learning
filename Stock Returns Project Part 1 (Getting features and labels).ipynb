# %% [markdown]
# # Stock Returns Prediction with Supervised Learning Algorithms
# ***

# %% [markdown]
# __Objective: To build and evaluate the performance of models based on various supervised machine learning algorithms to predict stock returns.__

# %% [markdown]
# The dataset to be used comprise all stocks listed on America's three stock exchanges: NYSE, AMEX and NASDAQ.
#
# New York Stock Exchange (__NYSE__): The largest American stock exchange by volume. Combined with Europe's Deutsche Boerse and Euronext exchanges, NYSE lists companies from all over the world.
#
# American Stock Exchange (__AMEX__): Favoured by smaller companies which cannot meet NYSE's strict listing and reporting requirements.
#
# National Association of Securities Dealers (__NASDAQ__): Unlike the other American exchanges, NASDAQ does not operate with a physical trading floor, increasing the exchange's cost efficiency. NASDAQ is traditionally heavy with tech stocks.
#
# Conveniently, the list of tickers for all stocks listed on the three stock exchanges can be found on the NASDAQ Stock Screener: https://www.nasdaq.com/market-activity/stocks/screener and downloaded as a csv file.

# %%
import numpy as np
import pandas as pd
import yfinance as yf
from datetime import datetime

# %%
# Data downloaded from NASDAQ Stock Screener on 05Jan2023 7am EST.
screener = pd.read_csv('nasdaq_screener_1672920378111.csv')
screener.head()
# Out:
#   Symbol                                               Name Last Sale  \
# 0      A             Agilent Technologies Inc. Common Stock   $151.67
# 1     AA                    Alcoa Corporation Common Stock     $45.13
# 2    AAC  Ares Acquisition Corporation Class A Ordinary ...    $10.10
# 3   AACG   ATA Creativity Global American Depositary Shares     $1.27
# 4   AACI            Armada Acquisition Corp. I Common Stock    $10.14
#
#    Net Change % Change    Market Cap        Country  IPO Year   Volume  \
# 0        1.63   1.086%  4.490525e+10  United States    1999.0  1247420
# 1        0.55   1.234%  7.985174e+09            NaN    2016.0  3523420
# 2       -0.01  -0.099%  1.262500e+09            NaN    2021.0  1529081
# 3        0.01   0.794%  3.984869e+07          China    2008.0     1350
# 4        0.01   0.099%  2.099943e+08  United States    2021.0     7253
#
#                    Sector                         Industry
# 0             Industrials              Electrical Products
# 1             Industrials               Metal Fabrications
# 2                 Finance                Business Services
# 3  Consumer Discretionary   Service to the Health Industry
# 4             Industrials  Consumer Electronics/Appliances

# %%
screener.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7826 entries, 0 to 7825
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Symbol      7825 non-null   object
#  1   Name        7826 non-null   object
#  2   Last Sale   7826 non-null   object
#  3   Net Change  7826 non-null   float64
#  4   % Change    7822 non-null   object
#  5   Market Cap  7372 non-null   float64
#  6   Country     7068 non-null   object
#  7   IPO Year    4629 non-null   float64
#  8   Volume      7826 non-null   int64
#  9   Sector      6924 non-null   object
#  10  Industry    6924 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 672.7+ KB

# %%
# To find the missing ticker symbol from the screener DataFrame 
screener[screener['Symbol'].isna()]
# Out:
#      Symbol                                      Name Last Sale  Net Change  \
# 4786    NaN  Nano Labs Ltd American Depositary Shares     $1.18       0.006
#
#      % Change  Market Cap Country  IPO Year  Volume      Sector  \
# 4786   0.511%  63324700.0   China    2022.0   16258  Technology
#
#             Industry
# 4786  Semiconductors

# %%
# 'NA' is the ticker symbol for Nano Labs Ltd ADS
# To reread the CSV file into a DataFrame but to remove 'NA' from default strings to be parsed as NaN
screener = pd.read_csv('nasdaq_screener_1672920378111.csv',keep_default_na=False,
                           na_values = ['', '#N/A', '#N/A N/A', '#NA', '-1.#IND', '-1.#QNAN', 
                                      '-NaN', '-nan', '1.#IND', '1.#QNAN', '<NA>', 'N/A', 
                                      'NULL', 'NaN', 'n/a','nan', 'null'])

# %%
screener.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7826 entries, 0 to 7825
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Symbol      7826 non-null   object
#  1   Name        7826 non-null   object
#  2   Last Sale   7826 non-null   object
#  3   Net Change  7826 non-null   float64
#  4   % Change    7822 non-null   object
#  5   Market Cap  7372 non-null   float64
#  6   Country     7068 non-null   object
#  7   IPO Year    4629 non-null   float64
#  8   Volume      7826 non-null   int64
#  9   Sector      6924 non-null   object
#  10  Industry    6924 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 672.7+ KB

# %%
screener['Symbol'].nunique()
# Out:
# 7826

# %%
tickers = screener['Symbol'].tolist()

# %%
# import seaborn and matplotlib for charting and data visualisation
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot')

# %%
#import plotly and cufflinks for interactive visualisations
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# To determine an appropriate time period for calculating stock returns by avoiding the selection of start and end dates at peaks or troughs of the economic cycle. 
# To do this, a historical price chart for the NYSE Composite will be plotted.
# The NYSE Composite is a stock market index covering all common stock listed on the New York Stock Exchange, including American depositary receipts, real estate investment trusts, tracking stocks, and foreign listings.
NYA_historical_price = yf.download('NYA',end='2022-12-31')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
NYA_historical_price
# Out:
#                                    Open          High           Low  \
# Date
# 1970-01-23 00:00:00-05:00    527.950012    527.950012    527.950012
# 1970-01-30 00:00:00-05:00    502.679993    502.679993    502.679993
# 1970-02-24 00:00:00-05:00    520.229980    520.229980    520.229980
# 1970-02-25 00:00:00-05:00    528.369995    528.369995    528.369995
# 1970-02-26 00:00:00-05:00    525.830017    525.830017    525.830017
# ...                                 ...           ...           ...
# 2022-02-24 00:00:00-05:00  15996.000000  15996.000000  15996.000000
# 2022-02-25 00:00:00-05:00  16428.000000  16428.000000  16428.000000
# 2022-02-28 00:00:00-05:00  16313.900391  16313.900391  16313.900391
# 2022-03-01 00:00:00-05:00  16069.200195  16069.200195  16069.200195
# 2022-03-02 00:00:00-05:00  16380.900391  16380.900391  16380.900391
#
#                                   Close     Adj Close  Volume
# Date
# 1970-01-23 00:00:00-05:00    527.950012    527.950012       0
# 1970-01-30 00:00:00-05:00    502.679993    502.679993       0
# 1970-02-24 00:00:00-05:00    520.229980    520.229980       0
# 1970-02-25 00:00:00-05:00    528.369995    528.369995       0
# 1970-02-26 00:00:00-05:00    525.830017    525.830017       0
# ...                                 ...           ...     ...
# 2022-02-24 00:00:00-05:00  15996.000000  15996.000000       0
# 2022-02-25 00:00:00-05:00  16428.000000  16428.000000       0
# 2022-02-28 00:00:00-05:00  16313.900391  16313.900391       0
# 2022-03-01 00:00:00-05:00  16069.200195  16069.200195       0
# 2022-03-02 00:00:00-05:00  16380.900391  16380.900391       0
#
# [11584 rows x 6 columns]

# %%
NYA_historical_price.iplot(y='Adj Close', 
                           title='NYSE COMPOSITE (^NYA) Price Chart', 
                           yTitle='Adjusted Close Price (USD)')
# Out:
# <div>                            <div id="01109ea2-4643-40ee-96c9-07206929a509" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("01109ea2-4643-40ee-96c9-07206929a509")) {                    Plotly.newPlot(                        "01109ea2-4643-40ee-96c9-07206929a509",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"Adj Close","text":"","x":["1970-01-23 00:00:00-05:00","1970-01-30 00:00:00-05:00","1970-02-24 00:00:00-05:00","1970-02-25 00:00:00-05:00","1970-02-26 00:00:00-05:00","1970-02-27 00:00:00-05:00","1970-03-23 00:00:00-05:00","1970-03-24 00:00:00-05:00","1970-03-25 00:00:00-05:00","1970-03-26 00:00:00-05:00","1970-03-30 00:00:00-05:00","1970-03-31 00:00:00-05:00","1970-04-23 00:00:00-05:00","1970-04-24 00:00:00-05:00","1970-04-27 00:00:00-04:00","1970-04-28 00:00:00-04:00","1970-04-29 00:00:00-04:00","1970-04-30 00:00:00-04:00","1970-05-25 00:00:00-04:00","1970-05-26 00:00:00-04:00","1970-05-27 00:00:00-04:00","1970-05-28 00:00:00-04:00","1970-05-29 00:00:00-04:00","1970-06-23 00:00:00-04:00","1970-06-24 00:00:00-04:00","1970-06-25 00:00:00-04:00","1970-06-26 00:00:00-04:00","1970-06-29 00:00:00-04:00","1970-06-30 00:00:00-04:00","1970-07-23 00:00:00-04:00","1970-07-24 00:00:00-04:00","1970-07-27 00:00:00-04:00","1970-07-28 00:00:00-04:00","1970-07-29 00:00:00-04:00","1970-07-30 00:00:00-04:00","1970-07-31 00:00:00-04:00","1970-08-24 00:00:00-04:00","1970-08-25 00:00:00-04:00","1970-08-26 00:00:00-04:00","1970-08-27 00:00:00-04:00","1970-08-28 00:00:00-04:00","1970-08-31 00:00:00-04:00","1970-09-23 00:00:00-04:00","1970-09-24 00:00:00-04:00","1970-09-25 00:00:00-04:00","1970-09-28 00:00:00-04:00","1970-09-29 00:00:00-04:00","1970-09-30 00:00:00-04:00","1970-10-23 00:00:00-04:00","1970-10-26 00:00:00-05:00","1970-10-27 00:00:00-05:00","1970-10-28 00:00:00-05:00","1970-10-29 00:00:00-05:00","1970-10-30 00:00:00-05:00","1970-11-23 00:00:00-05:00","1970-11-24 00:00:00-05:00","1970-11-25 00:00:00-05:00","1970-11-27 00:00:00-05:00","1970-11-30 00:00:00-05:00","1970-12-23 00:00:00-05:00","1970-12-24 00:00:00-05:00","1970-12-28 00:00:00-05:00","1970-12-29 00:00:00-05:00","1970-12-30 00:00:00-05:00","1970-12-31 00:00:00-05:00","1971-01-25 00:00:00-05:00","1971-01-26 00:00:00-05:00","1971-01-27 00:00:00-05:00","1971-01-28 00:00:00-05:00","1971-01-29 00:00:00-05:00","1971-02-23 00:00:00-05:00","1971-02-24 00:00:00-05:00","1971-02-25 00:00:00-05:00","1971-02-26 00:00:00-05:00","1971-03-23 00:00:00-05:00","1971-03-24 00:00:00-05:00","1971-03-25 00:00:00-05:00","1971-03-26 00:00:00-05:00","1971-03-29 00:00:00-05:00","1971-03-30 00:00:00-05:00","1971-03-31 00:00:00-05:00","1971-04-23 00:00:00-05:00","1971-04-26 00:00:00-04:00","1971-04-27 00:00:00-04:00","1971-04-28 00:00:00-04:00","1971-04-29 00:00:00-04:00","1971-04-30 00:00:00-04:00","1971-05-24 00:00:00-04:00","1971-05-25 00:00:00-04:00","1971-05-26 00:00:00-04:00","1971-05-27 00:00:00-04:00","1971-05-28 00:00:00-04:00","1971-06-23 00:00:00-04:00","1971-06-24 00:00:00-04:00","1971-06-25 00:00:00-04:00","1971-06-28 00:00:00-04:00","1971-06-29 00:00:00-04:00","1971-06-30 00:00:00-04:00","1971-07-23 00:00:00-04:00","1971-07-30 00:00:00-04:00","1971-08-23 00:00:00-04:00","1971-08-24 00:00:00-04:00","1971-08-25 00:00:00-04:00","1971-08-26 00:00:00-04:00","1971-08-27 00:00:00-04:00","1971-08-30 00:00:00-04:00","1971-08-31 00:00:00-04:00","1971-09-23 00:00:00-04:00","1971-09-24 00:00:00-04:00","1971-09-27 00:00:00-04:00","1971-09-28 00:00:00-04:00","1971-09-29 00:00:00-04:00","1971-09-30 00:00:00-04:00","1971-10-25 00:00:00-04:00","1971-10-26 00:00:00-04:00","1971-10-27 00:00:00-04:00","1971-10-28 00:00:00-04:00","1971-10-29 00:00:00-04:00","1971-11-30 00:00:00-05:00","1971-12-23 00:00:00-05:00","1971-12-27 00:00:00-05:00","1971-12-28 00:00:00-05:00","1971-12-29 00:00:00-05:00","1971-12-30 00:00:00-05:00","1971-12-31 00:00:00-05:00","1972-01-24 00:00:00-05:00","1972-01-25 00:00:00-05:00","1972-01-26 00 ...

# %% [markdown]
# From the historical price performance of the NYSE Composite:
# <br> Beginning of Jan-2010 is an appropriate start date as it is post the Global Financial Crisis in 2008.
# <br> Beginning of Jan-2020 can be selected as the end date for calculating historical stock returns as it is before Covid-19, a black swan event, affected financial markets.
# <br> Therefore, for our machine learning algorithms, <u>historical 10-year stock returns from beginning of Jan-2010 to beginning of Jan-2020 will be used as the learning label.<u>

# %%
# The first trading day of 2010 is 4-Jan-2010.
start_price = yf.download(tickers, start='2010-01-04', end='2010-01-05')
# Out:
# [*********************100%***********************]  7826 of 7826 completed
#
# 4874 Failed downloads:
# - HPP^C: No timezone found, symbol may be delisted
# - DH: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ENTA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AQST: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CHPT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GRAY: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RENN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AMBO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RCA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PLMIU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AGM^E: No timezone found, symbol may be delisted
# - FSRX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PYPD: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - TMCWW: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MTDR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - OKTA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - VNRX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - HUDAR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ROC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RFL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CTBB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - TRUE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GLST: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - VIIAW: Period 'max' is invalid, must be one of ['1d', '5d']
# - STOR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RILYM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - FINMU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - FOUR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RUBY: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NHICU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PONOW: Period 'max' is invalid, must be one of ['1d', '5d']
# - RLX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - VERBW: Period 'max' is invalid, must be one of ['1d', '5d']
# - PWUPW: Period 'max' is invalid, must be one of ['1d', '5d']
# - MNK: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - EMO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - EMCG: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ALLY: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - UROY: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - LIAN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AEACU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ORC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NSTB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SPRY: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RPD: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - EQBK: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GRNQ: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - KTRA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ALTIW: Period 'max' is invalid, must be one of ['1d', '5d']
# - EQH^C: No timezone found, symbol may be delisted
# - VSACU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PRIF^J: No timezone found, symbol may be delisted
# - FEXDW: Period 'max' is invalid, must be one of ['1d', '5d']
# - SDGR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BMEA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - COMSP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - JMSB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ALSN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - HUDI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CRKN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BYSI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - KBNT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - VERB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BCDAW: Period 'max' is invalid, must be one of ['1d', '5d']
# - INDIW: Period 'max' is invalid, must be one of ['1d', '5d']
# - TZPSU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PET: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AAIN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CHEF: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - VZIO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AVTX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - UPTDW: Period 'max' is invalid, must be one of ['1d', '5d']
# - FERG: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ROCL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - VNO^O: No timezone found, symbol may be delisted
# - INAQ: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - XPDBW: Period 'max' is invalid, must be one of ['1d', '5d']
# - JILL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - DRCT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NEE^Q: No timezone found, symbol may be delisted
# - AKAN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - INMB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GSMG: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - DDL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SGHC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - OSH: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SMRT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - STET: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AQUNR: Period 'max' is invalid, must be one of ['1d', '5d']
# - SERA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PMGMU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - COLD: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AGBA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PARAA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PINS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - THCP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MIT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MRCC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RLYB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ESACU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - IVR^C: No timezone found, symbol may be delisted
# - BRKHW: Period 'max' is invalid, must be one of ['1d', '5d']
# - DCOMP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - WDAY: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GTLS^B: No timezone found, symbol may be delisted
# - STOK: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - APAM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - DX^C: No timezone found, symbol may be delisted
# - VTGN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SNAX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AMH: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - KALWW: Period 'max' is invalid, must be one of ['1d', '5d']
# - SLGC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ATEK: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - KDNY: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PMT^B: No timezone found, symbol may be delisted
# - CPAQ: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - EE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - HCXY: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GFGDR: Period 'max' is invalid, must be one of ['1d', '5d']
# - DTC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CIFR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MTP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GAB^K: No timezone found, symbol may be delisted
# - SWIM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CUBI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - FXCOW: Period 'max' is invalid, must be one of ['1d', '5d']
# - SVFA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - LOB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - T^C: No timezone found, symbol may be delisted
# - CLDT^A: No timezone found, symbol may be delisted
# - SPLP^A: No timezone found, symbol may be delisted
# - VRA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - OLK: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - UNIT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BF/A: No timezone found, symbol may be delisted
# - GMFIU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - TNP^F: No timezone found, symbol may be delisted
# - JNCE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - STKH: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ZT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AMPY: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - FNWB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CMRAW: Period 'max' is invalid, must be one of ['1d', '5d']
# - LVOX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - DKDCA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - WEJO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - HEXO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GSRMU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - INST: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PRLH: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BPYPO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SIEN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AGNCO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SLN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SLVM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - DEN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - APTV^A: No timezone found, symbol may be delisted
# - ZVIA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AUBAP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - HTBI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RBKB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PUBM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AOMR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RHE^A: No timezone found, symbol may be delisted
# - ENTX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MRNA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - TRNO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NS^A: No timezone found, symbol may be delisted
# - RMGCW: Period 'max' is invalid, must be one of ['1d', '5d']
# - SCCE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - WMG: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PJT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MSSAR: Period 'max' is invalid, must be one of ['1d', '5d']
# - VBOC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AIMAU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - DCP^B: No timezone found, symbol may be delisted
# - ACHL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - FGFPP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MNTS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - TNXP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - EVE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - VRNA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ERYP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - INSP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PFDR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - THWWW: Period 'max' is invalid, must be one of ['1d', '5d']
# - VLNS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BGX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - TARS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ADVM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PRIF^F: No timezone found, symbol may be delisted
# - MYMD: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - APPHW: Period 'max' is invalid, must be one of ['1d', '5d']
# - NTB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ORLA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NIMC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MS^E: No timezone found, symbol may be delisted
# - BRZE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - TPHS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CTKB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PPBT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - EQRXW: Period 'max' is invalid, must be one of ['1d', '5d']
# - NHWK: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GDS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - XFIN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SCAQ: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - WRB^H: No timezone found, symbol may be delisted
# - TPH: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - HUT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CPAC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NXTC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ESRT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - WRB^G: No timezone found, symbol may be delisted
# - HOUS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SEAL^A: No timezone found, symbol may be delisted
# - NOVVW: Period 'max' is invalid, must be one of ['1d', '5d']
# - PRSRW: Period 'max' is invalid, must be one of ['1d', '5d']
# - GAMB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - DTSS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - VECT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - EFXT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - OLLI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SYTA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CPAQU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ONDS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - KKRS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - FRBNW: Period 'max' is invalid, must be one of ['1d', '5d']
# - TRGP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - TBC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AGTI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MVBF: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - VCXAW: Period 'max' is invalid, must be one of ['1d', '5d']
# - STBX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BAC^O: No timezone found, symbol may be delisted
# - ALLO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - LIQT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - COUP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MURFW: Period 'max' is invalid, must be one of ['1d', '5d']
# - ESNT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CLPS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PTON: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SLDB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - IPSC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - UNCY: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PRCH: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MPC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MNTV: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PBA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SFIX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ILPT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - OLITW: Period 'max' is invalid, must be one of ['1d', '5d']
# - SWTX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - INNV: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PUCKU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CSSEL: Period 'max' is invalid, must be one of ['1d', '5d']
# - SOUNW: Period 'max' is invalid, must be one of ['1d', '5d']
# - SCAQW: Period 'max' is invalid, must be one of ['1d', '5d']
# - IPW: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - TFC^O: No timezone found, symbol may be delisted
# - DTB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ORIC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SOLOW: Period 'max' is invalid, must be one of ['1d', '5d']
# - RWAYZ: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CHSCM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AQNB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SYRS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - STSS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AHRN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SGII: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - TSHA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PWSC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - KYMR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BALY: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ROAD: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AINC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - WRK: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - KMI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - COEP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BAC^N: No timezone found, symbol may be delisted
# - DSP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - FGF: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - LTRY: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MNDY: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ASCAW: Period 'max' is invalid, must be one of ['1d', '5d']
# - REKR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CENQW: Period 'max' is invalid, must be one of ['1d', '5d']
# - CVAC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MEGI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GRNT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GLSI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AMBC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - FTHY: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - KRNLW: Period 'max' is invalid, must be one of ['1d', '5d']
# - FHB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RRBI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SIGIP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - DARE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - INLX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - LEGH: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - VMD: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NEXT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BLZE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NINE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - DTG: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - TWKS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - WAFDP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ISUN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ARCK: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BRSHW: Period 'max' is invalid, must be one of ['1d', '5d']
# - AVIR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - XAIR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BY: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SCMA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AOGO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ERAS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - KLR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ATXI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - F^D: No timezone found, symbol may be delisted
# - ICCM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - VOC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - XERS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - TALK: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RVPHW: Period 'max' is invalid, must be one of ['1d', '5d']
# - SESN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - DHHC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - APGNW: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - IOACW: Period 'max' is invalid, must be one of ['1d', '5d']
# - EXPI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CCLP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GFGD: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ACI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - HMACW: Period 'max' is invalid, must be one of ['1d', '5d']
# - LBRDP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CMPS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - WES: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GGAA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GTAC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ARVL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - FRHC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AULT^D: No timezone found, symbol may be delisted
# - BAC^P: No timezone found, symbol may be delisted
# - SES: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BW^A: No timezone found, symbol may be delisted
# - ESTA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ENCP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AREBW: Period 'max' is invalid, must be one of ['1d', '5d']
# - REVBW: Period 'max' is invalid, must be one of ['1d', '5d']
# - SEDG: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MDIA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CNEY: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - HYMC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NFYS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NREF^A: No timezone found, symbol may be delisted
# - ZNTL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CEPU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SBFM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - KRUS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BGRY: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NMTC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - LVOXW: Period 'max' is invalid, must be one of ['1d', '5d']
# - LQDA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BRKH: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NESRW: Period 'max' is invalid, must be one of ['1d', '5d']
# - KNTK: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RTLPP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AFARU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - WSC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - C^N: No timezone found, symbol may be delisted
# - QSIAW: Period 'max' is invalid, must be one of ['1d', '5d']
# - FZT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NEXA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ISPOW: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RNWWW: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ECCW: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CELZ: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CLAA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CRDL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RELIW: Period 'max' is invalid, must be one of ['1d', '5d']
# - LUMO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BAC^M: No timezone found, symbol may be delisted
# - ADNT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BCC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - IDAI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RENT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GBTG: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AEAEW: Period 'max' is invalid, must be one of ['1d', '5d']
# - IMCR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PICC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NLY^I: No timezone found, symbol may be delisted
# - IPDN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AVAL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SPWH: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - EPHYW: Period 'max' is invalid, must be one of ['1d', '5d']
# - PHGE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CWAN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ACP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SNDX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CHX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CWBR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SAFE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - STEL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MBINM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - FRBN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SCPH: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MSBI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - REYN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BFS^E: No timezone found, symbol may be delisted
# - CIIGW: Period 'max' is invalid, must be one of ['1d', '5d']
# - MSBIP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NTLA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - VCXA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ARVN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - HPLT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ENTFU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - TIOA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MBINO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - LPTX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ENV: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - UNMA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - TLS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GDOT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MFGP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BILL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - TGVC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SABSW: Period 'max' is invalid, must be one of ['1d', '5d']
# - DFH: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ATY: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - HTGM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PSA^P: No timezone found, symbol may be delisted
# - SQ: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CMSD: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - WWAC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CFG^D: No timezone found, symbol may be delisted
# - BNR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AMRK: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ROCGW: Period 'max' is invalid, must be one of ['1d', '5d']
# - HYZNW: Period 'max' is invalid, must be one of ['1d', '5d']
# - DTOCW: Period 'max' is invalid, must be one of ['1d', '5d']
# - BIO/B: No timezone found, symbol may be delisted
# - AMPS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SDPI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ASAI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - VRAX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - KALA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - EJH: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PRFX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - DAVE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - OMIC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BLDE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NYMTM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - FRBNU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CTGO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RVNC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - TGH^B: No timezone found, symbol may be delisted
# - FGEN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ARCE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - VNO^N: No timezone found, symbol may be delisted
# - SGHL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AXLA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - TOST: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - KITTW: Period 'max' is invalid, must be one of ['1d', '5d']
# - GLS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RFMZ: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MBIN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NVST: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BSMX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - HYPR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - INMD: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - DBRG^J: No timezone found, symbol may be delisted
# - UPLD: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - FAMI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CHMI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - DBRG^I: No timezone found, symbol may be delisted
# - MACK: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NXGLW: Period 'max' is invalid, must be one of ['1d', '5d']
# - VMAR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - REAL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ILAG: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - INZY: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - EM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ATCX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GRCL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NSPR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - KN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - F^C: No timezone found, symbol may be delisted
# - PACB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - IVCAW: Period 'max' is invalid, must be one of ['1d', '5d']
# - PTCT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BRCC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RNER: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SILV: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - OPINL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PRTC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - XOMAP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BLMN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - HRZN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AZRE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - S: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GOEVW: Period 'max' is invalid, must be one of ['1d', '5d']
# - SMHI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - EVTV: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SNPX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - DMAC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CDW: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - FGI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PFXNL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GFAI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - QFTA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - LGVC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - LPCN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SGBX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CAN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - DNUT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - HLBZW: Period 'max' is invalid, must be one of ['1d', '5d']
# - RLJ: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - EAF: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - LICY: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RUN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - VICI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - HPX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SNAP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AUST: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ARGD: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - FNCH: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - LYLT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - OTLK: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BMBL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - APGN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MGNI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - U: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RBLX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NBST: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - HERA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GRNA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BCYC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PEN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BLD: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NNOX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GRCYU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - DAVA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MTBC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - EDSA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ORGS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NRGV: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - FWBI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - HASI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - XOMAO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NH: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PEB^E: No timezone found, symbol may be delisted
# - XPEV: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RGTIW: Period 'max' is invalid, must be one of ['1d', '5d']
# - CORS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ECCV: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - LAUR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - LUCD: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RNLX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - THW: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SNV^E: No timezone found, symbol may be delisted
# - MCAA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - IVH: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CANB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PMCB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - DUNEW: Period 'max' is invalid, must be one of ['1d', '5d']
# - IPVIU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ASMB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MET^E: No timezone found, symbol may be delisted
# - OAK^A: No timezone found, symbol may be delisted
# - VTEX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - HCNEU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SXC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - QLI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BAM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - XWEL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - VPCB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SHAP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - FLNG: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - HAIA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PHIO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ALLG: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BBDO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SOVO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - HTIA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - DPG: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CANF: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - COOLU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NAMS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NEWTL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - LAND: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - LFT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ARBK: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - STNG: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - TIOAW: Period 'max' is invalid, must be one of ['1d', '5d']
# - CGBD: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - TMDX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - VAQC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - VBLT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RIOT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RILYG: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ATAT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CRD/B: No timezone found, symbol may be delisted
# - PNFPP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AVRO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ACR^D: No timezone found, symbol may be delisted
# - PROK: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AMC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - FGBIP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AAM^A: No timezone found, symbol may be delisted
# - AFRIW: Period 'max' is invalid, must be one of ['1d', '5d']
# - MCACW: Period 'max' is invalid, must be one of ['1d', '5d']
# - AKA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - IDE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - VOYA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ARIS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PYR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ATEX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SAMAW: Period 'max' is invalid, must be one of ['1d', '5d']
# - ONEM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BSIG: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - EZGO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ACABW: Period 'max' is invalid, must be one of ['1d', '5d']
# - PATI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - HMST: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NSA^A: No timezone found, symbol may be delisted
# - MSGM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - EDRY: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SQNS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - UZD: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - HOOD: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - VLN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GIA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ATMCU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - LSF: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - JEWL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BHFAP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NUVL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ENVX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BRAC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - TALO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - FICV: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - JUPWW: Period 'max' is invalid, must be one of ['1d', '5d']
# - IVA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - LILMW: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ACT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RBOT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GECCO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - VCYT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - DT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MOTS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CODX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BZUN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NETI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SVRE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - HTOO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# ...
# - BIOTU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ATH^A: No timezone found, symbol may be delisted
# - ZIONO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - OXUSW: Period 'max' is invalid, must be one of ['1d', '5d']
# - IPVI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BWAQ: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - KALV: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CHMI^B: No timezone found, symbol may be delisted
# - QNRX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - DHHCU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PDO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - OPP^A: No timezone found, symbol may be delisted
# - LATGU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RDVT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PTIX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ESGRP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ARQT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - IRNT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - REXR^C: No timezone found, symbol may be delisted
# - BLBX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PROF: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MCAER: Period 'max' is invalid, must be one of ['1d', '5d']
# - ADSEW: Period 'max' is invalid, must be one of ['1d', '5d']
# - PHAR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ACB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AGNCP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ZI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PAGP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - TCRR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CTOS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CNO^A: No timezone found, symbol may be delisted
# - EEIQ: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NMG: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PLTK: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - UAN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MCAF: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - DWACW: Period 'max' is invalid, must be one of ['1d', '5d']
# - ECC           : No timezone found, symbol may be delisted
# - FN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CPOP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GBBK: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BTCS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NMRK: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - KHC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ARCO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BEAM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CALT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - IGMS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - EARN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PEV: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - UA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ZING: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - VINC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - WRB^F: No timezone found, symbol may be delisted
# - GATEW: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RILYK: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MGLD: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - USB^R: No timezone found, symbol may be delisted
# - DNMR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - APM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - JSD: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - EAC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ALOR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PSN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - FANG: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NTRA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - OMGA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - VNTR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ASPU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - APRN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ADOCR: Period 'max' is invalid, must be one of ['1d', '5d']
# - ZTAQU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - TYRA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - KRTX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - FRC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SLAMU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PFIE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PFX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RZB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RCRTW: Period 'max' is invalid, must be one of ['1d', '5d']
# - AMCX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MBTCR: Period 'max' is invalid, must be one of ['1d', '5d']
# - TSQ: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GATO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GSQD: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ACIU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SELB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - TALS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - IMPL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GDDY: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - XYF: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AQNU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MBNKP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - JCSE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MITQ: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - HR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - LDHAW: Period 'max' is invalid, must be one of ['1d', '5d']
# - SBOW: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NPFD: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BODY: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - DERM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SLDP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PSA^F: No timezone found, symbol may be delisted
# - TNP^E: No timezone found, symbol may be delisted
# - CFFE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SLAMW: Period 'max' is invalid, must be one of ['1d', '5d']
# - NRAC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ACAC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SCWX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ARBE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AEAE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - XBIO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SMLR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - EVOK: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BTWNU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MAXN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SQL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BSAQ: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - IRRX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SYF^A: No timezone found, symbol may be delisted
# - MRUS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MTAL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CNDB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GTHX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SF^C: No timezone found, symbol may be delisted
# - APE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - OXSQL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SATL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - WD: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - OMF: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SILK: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RMBL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - TRON: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - STAR^I: No timezone found, symbol may be delisted
# - SGFY: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SPCMU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ARBGW: Period 'max' is invalid, must be one of ['1d', '5d']
# - EOSEW: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - LILM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CNFRL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ECVT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RCKT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ANET: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - WTFCM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ASCAR: Period 'max' is invalid, must be one of ['1d', '5d']
# - ENTFW: Period 'max' is invalid, must be one of ['1d', '5d']
# - STIX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NXLIW: Period 'max' is invalid, must be one of ['1d', '5d']
# - FWONK: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - DNLI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AGGR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AADI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - EVLVW: Period 'max' is invalid, must be one of ['1d', '5d']
# - AMST: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SCUA: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - IVR^B: No timezone found, symbol may be delisted
# - PSA^H: No timezone found, symbol may be delisted
# - FFWM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GEHI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GTX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - DOMO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GRFS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BGXX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - IFRX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - PCG^B: No timezone found, symbol may be delisted
# - TKNO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BMAQU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AGM^C: No timezone found, symbol may be delisted
# - AGNCM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CMRE^C: No timezone found, symbol may be delisted
# - TWO^B: No timezone found, symbol may be delisted
# - ZIONL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - IAS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SACH: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - LYEL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ATHM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - NVEE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - DATSW: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MMYT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ATCO^D: No timezone found, symbol may be delisted
# - BYTS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - FOXF: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BIOX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CNCE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - LKCO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - APMI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - HCP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ROCC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SKYAU: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - EVAX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - GNFT: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - ALTG: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MIGI: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CELC: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - AMWL: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MTLS: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MOLN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - VKTX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SAGE: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - HYMCW: Period 'max' is invalid, must be one of ['1d', '5d']
# - SLG^I: No timezone found, symbol may be delisted
# - AFGD: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - LTH: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MGNX: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - BBIO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - FVCB: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - TCMD: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - FUBO: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CNM: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - INGN: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SMLP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - CYBR: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - OTRKP: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - SG: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - MSACW: Period 'max' is invalid, must be one of ['1d', '5d']
# - NAOV: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - IFBD: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - RELY: Data doesn't exist for startDate = 1262581200, endDate = 1262667600
# - WHF: Data doesn't exist for startDate = 1262581200, endDate = 1262667600

# %%
start_price.transpose().to_csv('start_price.csv')

# %%
# The first trading day of 2020 is 2-Jan-2020.
end_price = yf.download(tickers, start='2020-01-02', end='2020-01-03')
# Out:
# [*********************100%***********************]  7826 of 7826 completed
#
# 2949 Failed downloads:
# - PYPD: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ROC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - DH: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HPP^C: No timezone found, symbol may be delisted
# - GRAY: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AZ: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SQZ: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BRSHW: Period 'max' is invalid, must be one of ['1d', '5d']
# - BUR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CTA^B: No timezone found, symbol may be delisted
# - FINMW: Period 'max' is invalid, must be one of ['1d', '5d']
# - APG: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FOUR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FINMU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BWMN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GIA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TWO^B: No timezone found, symbol may be delisted
# - THCHW: Period 'max' is invalid, must be one of ['1d', '5d']
# - UROY: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - LIAN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AEACU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NSTB: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SSBK: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - USB^Q: No timezone found, symbol may be delisted
# - PKBO: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BON: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CDAK: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ALTIW: Period 'max' is invalid, must be one of ['1d', '5d']
# - EQH^C: No timezone found, symbol may be delisted
# - PRIF^J: No timezone found, symbol may be delisted
# - BMEA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - COMSP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HUDI: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FEXDW: Period 'max' is invalid, must be one of ['1d', '5d']
# - CRKN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TZPSU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AAIN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SMAP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - INDIW: Period 'max' is invalid, must be one of ['1d', '5d']
# - ROCL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - VNO^O: No timezone found, symbol may be delisted
# - XPDBW: Period 'max' is invalid, must be one of ['1d', '5d']
# - UPTDW: Period 'max' is invalid, must be one of ['1d', '5d']
# - AKAN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - DDL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ARR^C: No timezone found, symbol may be delisted
# - OSH: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - STET: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SERA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AQUNR: Period 'max' is invalid, must be one of ['1d', '5d']
# - APXI: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GLSTR: Period 'max' is invalid, must be one of ['1d', '5d']
# - SJIV: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - THCP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ESACU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MIT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ASAN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GTLS^B: No timezone found, symbol may be delisted
# - DX^C: No timezone found, symbol may be delisted
# - SLGC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - IMRA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - EE: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - DTC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PRBM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CIFR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GFGDR: Period 'max' is invalid, must be one of ['1d', '5d']
# - SWIM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BF/A: No timezone found, symbol may be delisted
# - BNNR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GAB^K: No timezone found, symbol may be delisted
# - T^C: No timezone found, symbol may be delisted
# - OLK: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SPLP^A: No timezone found, symbol may be delisted
# - CLDT^A: No timezone found, symbol may be delisted
# - IINN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - IMGO: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - DTOCU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - DKDCA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CMRAW: Period 'max' is invalid, must be one of ['1d', '5d']
# - STKH: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HT^E: No timezone found, symbol may be delisted
# - SLN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PHYT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PRLH: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SLVM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - IVCB: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AUBAP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PUBM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AOMR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RHE^A: No timezone found, symbol may be delisted
# - NS^A: No timezone found, symbol may be delisted
# - WMG: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AIMAU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - DCP^B: No timezone found, symbol may be delisted
# - VBOC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - EVE: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PRIF^F: No timezone found, symbol may be delisted
# - THWWW: Period 'max' is invalid, must be one of ['1d', '5d']
# - FRT^C: No timezone found, symbol may be delisted
# - NIMC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CRC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - KRNL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CTKB: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - EQRXW: Period 'max' is invalid, must be one of ['1d', '5d']
# - SCAQ: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - WRB^H: No timezone found, symbol may be delisted
# - GBRGR: Period 'max' is invalid, must be one of ['1d', '5d']
# - SEAL^A: No timezone found, symbol may be delisted
# - WSBCP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GAMB: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - VRM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ROSEU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SYTA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PRSRW: Period 'max' is invalid, must be one of ['1d', '5d']
# - ONDS: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - KKRS: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CPAQU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BPTS: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FRBNW: Period 'max' is invalid, must be one of ['1d', '5d']
# - VCXAW: Period 'max' is invalid, must be one of ['1d', '5d']
# - STBX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TASK: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SI^A: No timezone found, symbol may be delisted
# - IPSC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MURFW: Period 'max' is invalid, must be one of ['1d', '5d']
# - UNCY: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - IQMD: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ALTUW: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - INNV: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PUCKU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - IGTA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - POWWP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CYTHW: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SATLW: Period 'max' is invalid, must be one of ['1d', '5d']
# - DTB: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ORIC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SCAQW: Period 'max' is invalid, must be one of ['1d', '5d']
# - GAB^H: No timezone found, symbol may be delisted
# - PX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BTBD: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SOLOW: Period 'max' is invalid, must be one of ['1d', '5d']
# - AHRN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - STSS: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BCTXW: Period 'max' is invalid, must be one of ['1d', '5d']
# - SGII: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TSHA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - XELAP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - KYMR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - COEP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NS^C: No timezone found, symbol may be delisted
# - AEHAW: Period 'max' is invalid, must be one of ['1d', '5d']
# - DSP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BAC^N: No timezone found, symbol may be delisted
# - NCRA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MNDY: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RSI: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ASCAW: Period 'max' is invalid, must be one of ['1d', '5d']
# - CVAC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MEGI: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - LHDX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GLSI: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CENQW: Period 'max' is invalid, must be one of ['1d', '5d']
# - IVDAW: Period 'max' is invalid, must be one of ['1d', '5d']
# - GDRX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - KRNLW: Period 'max' is invalid, must be one of ['1d', '5d']
# - SIGIP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BLZE: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CRESW: Period 'max' is invalid, must be one of ['1d', '5d']
# - AGM^E: No timezone found, symbol may be delisted
# - RCA: No data found for this date range, symbol may be delisted
# - AVIR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PETVW: Period 'max' is invalid, must be one of ['1d', '5d']
# - AOGO: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SCMA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NYCB^U: No timezone found, symbol may be delisted
# - TALK: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - F^D: No timezone found, symbol may be delisted
# - RVPHW: Period 'max' is invalid, must be one of ['1d', '5d']
# - GEHC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TWND: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - DHHC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ELYM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FCRX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HITI: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ACI: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GFGD: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - INKAU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CMPS: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - LBRDP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AULT^D: No timezone found, symbol may be delisted
# - GGAA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GTAC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - IOACW: Period 'max' is invalid, must be one of ['1d', '5d']
# - ARVL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - OLMA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BAC^P: No timezone found, symbol may be delisted
# - SES: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ENCP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FFIEW: Period 'max' is invalid, must be one of ['1d', '5d']
# - CCAI: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BW^A: No timezone found, symbol may be delisted
# - MDIA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - REVBW: Period 'max' is invalid, must be one of ['1d', '5d']
# - CPTN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HYMCL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AREBW: Period 'max' is invalid, must be one of ['1d', '5d']
# - DIBS: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ZNTL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BRKH: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BNIX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BGRY: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RENEU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NESRW: Period 'max' is invalid, must be one of ['1d', '5d']
# - AFARU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - KMPB: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MIRO: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AHT^H: No timezone found, symbol may be delisted
# - LVOXW: Period 'max' is invalid, must be one of ['1d', '5d']
# - AIRC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - C^N: No timezone found, symbol may be delisted
# - CTAQ: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FZT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ISPOW: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ECCW: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - VNO^L: No timezone found, symbol may be delisted
# - PFTA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FIACW: Period 'max' is invalid, must be one of ['1d', '5d']
# - RELIW: Period 'max' is invalid, must be one of ['1d', '5d']
# - IMCR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GBTG: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PICC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NLY^I: No timezone found, symbol may be delisted
# - TMCWW: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CWAN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - INN^E: No timezone found, symbol may be delisted
# - FRBN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BRK/B: No timezone found, symbol may be delisted
# - MSBIP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AREB: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - REYN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - VCXA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HPLT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ENTFU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PHAR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TIOA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ECC           : No timezone found, symbol may be delisted
# - CPOP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GBBK: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GSQD: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - IMPL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CFG^D: No timezone found, symbol may be delisted
# - WWAC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - JCSE: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BIO/B: No timezone found, symbol may be delisted
# - AMPS: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ROCGW: Period 'max' is invalid, must be one of ['1d', '5d']
# - ASAI: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - VRAX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - EJH: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - OMIC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PRFX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - IAS: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TGH^B: No timezone found, symbol may be delisted
# - SGHL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MSACW: Period 'max' is invalid, must be one of ['1d', '5d']
# - TOST: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GLS: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RFMZ: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HYPR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - DBRG^J: No timezone found, symbol may be delisted
# - DBRG^I: No timezone found, symbol may be delisted
# - VMAR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - INZY: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ILAG: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - EM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GRCL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NXGLW: Period 'max' is invalid, must be one of ['1d', '5d']
# - RNER: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - IVCAW: Period 'max' is invalid, must be one of ['1d', '5d']
# - OPINL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - F^C: No timezone found, symbol may be delisted
# - PRTC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GLST: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - XOMAP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - S: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GOEVW: Period 'max' is invalid, must be one of ['1d', '5d']
# - GFAI: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FGI: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SNPX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PFXNL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - LGVC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - QFTA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HLBZW: Period 'max' is invalid, must be one of ['1d', '5d']
# - DNUT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - LICY: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HPX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AUST: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FNCH: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - APGN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BMBL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - LYLT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - U: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NBST: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RBLX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HERA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GRNA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NNOX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GRCYU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NRGV: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PEB^E: No timezone found, symbol may be delisted
# - XOMAO: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - XPEV: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CORS: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RGTIW: Period 'max' is invalid, must be one of ['1d', '5d']
# - ECCV: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - LUCD: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RILYM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MCAA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SNV^E: No timezone found, symbol may be delisted
# - DUNEW: Period 'max' is invalid, must be one of ['1d', '5d']
# - VTEX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - IPVIU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HCNEU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - OAK^A: No timezone found, symbol may be delisted
# - MET^E: No timezone found, symbol may be delisted
# - QLI: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - VPCB: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BAM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HAIA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SHAP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ALLG: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SOVO: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - COOLU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NAMS: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ARBK: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TIOAW: Period 'max' is invalid, must be one of ['1d', '5d']
# - VAQC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RILYG: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ATAT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CRD/B: No timezone found, symbol may be delisted
# - PNFPP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ACR^D: No timezone found, symbol may be delisted
# - PROK: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AFRIW: Period 'max' is invalid, must be one of ['1d', '5d']
# - FGBIP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AAM^A: No timezone found, symbol may be delisted
# - MCACW: Period 'max' is invalid, must be one of ['1d', '5d']
# - RLX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AKA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ARIS: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ONEM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SAMAW: Period 'max' is invalid, must be one of ['1d', '5d']
# - ACABW: Period 'max' is invalid, must be one of ['1d', '5d']
# - EZGO: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NSA^A: No timezone found, symbol may be delisted
# - MSGM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - UZD: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HOOD: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - VLN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ATMCU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - JEWL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NUVL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - LSF: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PWUPW: Period 'max' is invalid, must be one of ['1d', '5d']
# - ENVX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BRAC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MNK: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FICV: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - IVA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - EMCG: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ACT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - LILMW: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - JUPWW: Period 'max' is invalid, must be one of ['1d', '5d']
# - RBOT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GECCO: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SVRE: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HTOO: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AGGRW: Period 'max' is invalid, must be one of ['1d', '5d']
# - DLR^L: No timezone found, symbol may be delisted
# - PSA^G: No timezone found, symbol may be delisted
# - DECAU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CD: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PFH: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - EHAB: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TKLF: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RNW: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - VZLA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - DDI: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - EOSE: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - LEV: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CDIO: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - VOYA^B: No timezone found, symbol may be delisted
# - DADA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AGM^G: No timezone found, symbol may be delisted
# - INVZW: Period 'max' is invalid, must be one of ['1d', '5d']
# - PEGR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CDAQU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TRDA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - WTMAR: Period 'max' is invalid, must be one of ['1d', '5d']
# - AQUNU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CNOBP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SHCRW: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RNERW: Period 'max' is invalid, must be one of ['1d', '5d']
# - TPBA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - OGN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SONDW: Period 'max' is invalid, must be one of ['1d', '5d']
# - KCGI: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BOWL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TWLVW: Period 'max' is invalid, must be one of ['1d', '5d']
# - AHH^A: No timezone found, symbol may be delisted
# - SPRY: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - EVLV: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NCACW: Period 'max' is invalid, must be one of ['1d', '5d']
# - BOLT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MURFU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HBANM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RTLPO: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TENK: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TIVC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GXIIW: Period 'max' is invalid, must be one of ['1d', '5d']
# - NAUT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NEE^N: No timezone found, symbol may be delisted
# - FG: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BRLIW: Period 'max' is invalid, must be one of ['1d', '5d']
# - BRLT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ASCAU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TRTL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SNRH: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - XFLT^A: No timezone found, symbol may be delisted
# - DSEY: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - EFC^A: No timezone found, symbol may be delisted
# - GPAC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AAM^B: No timezone found, symbol may be delisted
# - CRDO: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - STVN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MEKA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - VIGL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - DCRD: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - USCB: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - DTRTW: Period 'max' is invalid, must be one of ['1d', '5d']
# - SMIH: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RITM^A: No timezone found, symbol may be delisted
# - VTRU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FTHM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GLUE: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PACWP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ECBK: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FRXB: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MLNK: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CHKEL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ACAQ: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CCTS: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CMRA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TNP^D: No timezone found, symbol may be delisted
# - VSACU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - APMIU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - EQC^D: No timezone found, symbol may be delisted
# - CARR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - UPST: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AZYO: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BDXB: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SCCF: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - EUCR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HUIZ: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - YTPG: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SGIIW: Period 'max' is invalid, must be one of ['1d', '5d']
# - DCRDU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BCAB: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - LGHLW: Period 'max' is invalid, must be one of ['1d', '5d']
# - ANNX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HTZWW: Period 'max' is invalid, must be one of ['1d', '5d']
# - IMMX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ET^C: No timezone found, symbol may be delisted
# - PGYWW: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SAT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FICVU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GGROW: Period 'max' is invalid, must be one of ['1d', '5d']
# - BYTSW: Period 'max' is invalid, must be one of ['1d', '5d']
# - LMDXW: Period 'max' is invalid, must be one of ['1d', '5d']
# - ALGM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RCACU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RBT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SDGR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HHGCW: Period 'max' is invalid, must be one of ['1d', '5d']
# - GSRMR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - JFBR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - XPAX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GMBLW: Period 'max' is invalid, must be one of ['1d', '5d']
# - CCVI: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SVFAW: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NEE^P: No timezone found, symbol may be delisted
# - DCT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AUGX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SLQT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - EPOW: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HT^C: No timezone found, symbol may be delisted
# - RAIN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CCAP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - OXLCN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MS^F: No timezone found, symbol may be delisted
# - ECXWW: Period 'max' is invalid, must be one of ['1d', '5d']
# - FICVW: Period 'max' is invalid, must be one of ['1d', '5d']
# - RAMMU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TBCP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GNS: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PDOT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ICUCW: Period 'max' is invalid, must be one of ['1d', '5d']
# - ATHA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BYN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - YCBD^A: No timezone found, symbol may be delisted
# - FIP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - VHAQ: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HKD: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - DPCSW: Period 'max' is invalid, must be one of ['1d', '5d']
# - LU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - UPXI: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SNCY: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - LTRN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GS^J: No timezone found, symbol may be delisted
# - DLCAU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GOVX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BF/B: No timezone found, symbol may be delisted
# - XM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - VHNA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GS^D: No timezone found, symbol may be delisted
# - LIDRW: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - IGAC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RMGC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FEAM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ALL^B: No timezone found, symbol may be delisted
# - CINT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - UGIC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - USCTW: Period 'max' is invalid, must be one of ['1d', '5d']
# - NGC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MAPSW: Period 'max' is invalid, must be one of ['1d', '5d']
# - SBIG: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GBIO: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RJF^B: No timezone found, symbol may be delisted
# - BAC^Q: No timezone found, symbol may be delisted
# - ACAH: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GVCIW: Period 'max' is invalid, must be one of ['1d', '5d']
# - WPCA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CVRX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GSRM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - COIN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TCBC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - DOLE: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MEAC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - KYCHR: Period 'max' is invalid, must be one of ['1d', '5d']
# - STRC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FRONU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MAX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - KBNT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - KNSW: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CFFS: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PLRX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FLAG: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - EVTL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AVAC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GRBK^A: No timezone found, symbol may be delisted
# - BCDAW: Period 'max' is invalid, must be one of ['1d', '5d']
# - KROS: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FRC^N: No timezone found, symbol may be delisted
# - CERT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PIII: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CVII: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HMAC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FREY: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PET: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - EFTRW: Period 'max' is invalid, must be one of ['1d', '5d']
# - ANGN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - OCAXW: Period 'max' is invalid, must be one of ['1d', '5d']
# - GLP^B: No timezone found, symbol may be delisted
# - MGRD: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - JWAC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SEMR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AHT^I: No timezone found, symbol may be delisted
# - SDAC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - OPT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TCBS: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GROV: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NETC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - KYCH: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ADCT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ACQRW: Period 'max' is invalid, must be one of ['1d', '5d']
# - REAX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SURGW: Period 'max' is invalid, must be one of ['1d', '5d']
# - FATP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TOIIW: Period 'max' is invalid, must be one of ['1d', '5d']
# - TPBAW: Period 'max' is invalid, must be one of ['1d', '5d']
# - GENQU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GOCO: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MS^L: No timezone found, symbol may be delisted
# - HCNE: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FINM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ADOC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NOGN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PCCT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - IHS: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - VZIO: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AMAM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MQ: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AFGC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NYMTZ: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PAYO: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ICVX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NEE^R: No timezone found, symbol may be delisted
# - MS^A: No timezone found, symbol may be delisted
# - DRUG: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - IPAXW: Period 'max' is invalid, must be one of ['1d', '5d']
# - PSA^O: No timezone found, symbol may be delisted
# - BLNG: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AMPG: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TFINP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - VLDRW: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - REVB: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ACLX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NCZ^A: No timezone found, symbol may be delisted
# - IVCBU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - INAQ: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BFLY: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TPTA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BNL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CDR^B: No timezone found, symbol may be delisted
# - NBXG: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HWM^: No timezone found, symbol may be delisted
# - GBNH: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - DNAB: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CIM^D: No timezone found, symbol may be delisted
# - CNGL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ALL^I: No timezone found, symbol may be delisted
# - REFI: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RLTY: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FATBW: Period 'max' is invalid, must be one of ['1d', '5d']
# - VRPX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MRVI: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AGNCL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - DRCT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TCRX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PAXS: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AGM^D: No timezone found, symbol may be delisted
# - ATMVU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - LOKM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - WQGA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PACI: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FRC^H: No timezone found, symbol may be delisted
# - LDHA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ATH^E: No timezone found, symbol may be delisted
# - ANGH: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FLUX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BSBK: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - DCGO: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CSTA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - OXUSU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MNSBP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ANAC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SCRMU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - STRE: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NEE^Q: No timezone found, symbol may be delisted
# - ASPA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - VBOCU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - EICA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ECX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ATAKR: Period 'max' is invalid, must be one of ['1d', '5d']
# - AAC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CURIW: Period 'max' is invalid, must be one of ['1d', '5d']
# - ATNFW: Period 'max' is invalid, must be one of ['1d', '5d']
# - CLINU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - REBN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PEB^G: No timezone found, symbol may be delisted
# - DPCSU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SGHC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TFSA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TRTN^C: No timezone found, symbol may be delisted
# - BRD: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SMRT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - LVAC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CING: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# ...
# - JMAC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ICR^A: No timezone found, symbol may be delisted
# - NFNT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - DAWN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - IMCC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - VERBW: Period 'max' is invalid, must be one of ['1d', '5d']
# - DRTS: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - JUGGU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SCCG: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ZFOXW: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SCHW^J: No timezone found, symbol may be delisted
# - BAC^M: No timezone found, symbol may be delisted
# - SMFR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NCNO: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - OST: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - VCXB: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AMLX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GGR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - UBP^K: No timezone found, symbol may be delisted
# - IDAI: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CPAR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BMN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RENT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RSKD: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AEAEW: Period 'max' is invalid, must be one of ['1d', '5d']
# - MBLY: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - VMGAU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RMMZ: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FMIVW: Period 'max' is invalid, must be one of ['1d', '5d']
# - FSBC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PONOU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PRPC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AVPTW: Period 'max' is invalid, must be one of ['1d', '5d']
# - PSB^X: No timezone found, symbol may be delisted
# - EOCW: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - OTIS: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FRMEP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CMS^B: No timezone found, symbol may be delisted
# - ERESW: Period 'max' is invalid, must be one of ['1d', '5d']
# - MGRB: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - UCBIO: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ENTF: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - EPHYW: Period 'max' is invalid, must be one of ['1d', '5d']
# - TRTX^C: No timezone found, symbol may be delisted
# - DALN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - VWE: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - VACC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RLAY: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - LION: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MSSA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FPAC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - JCIC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PLBY: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - LIXTW: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - KWESW: Period 'max' is invalid, must be one of ['1d', '5d']
# - SITC^A: No timezone found, symbol may be delisted
# - BHACW: Period 'max' is invalid, must be one of ['1d', '5d']
# - DSX^B: No timezone found, symbol may be delisted
# - MSSAW: Period 'max' is invalid, must be one of ['1d', '5d']
# - FATBP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NFGC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ALLR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TRAQ: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MOND: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - EVCM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RKLB: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MSDAU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TGAN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CVT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HYZN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TBLD: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - IRAAU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - POWRU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - IGICW: Period 'max' is invalid, must be one of ['1d', '5d']
# - AMPX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MBINM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RC^E: No timezone found, symbol may be delisted
# - ALSA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FULTP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SBBA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - GS^C: No timezone found, symbol may be delisted
# - GLLIW: Period 'max' is invalid, must be one of ['1d', '5d']
# - VWEWW: Period 'max' is invalid, must be one of ['1d', '5d']
# - KWE: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - F^B: No timezone found, symbol may be delisted
# - ASTR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FXCO: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ANZUW: Period 'max' is invalid, must be one of ['1d', '5d']
# - MDV: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MAIA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - DNA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PCGU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BCSAW: Period 'max' is invalid, must be one of ['1d', '5d']
# - BFS^E: No timezone found, symbol may be delisted
# - PXSAW: Period 'max' is invalid, must be one of ['1d', '5d']
# - EMCGU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CYXT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CIIGW: Period 'max' is invalid, must be one of ['1d', '5d']
# - GCT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - DOUG: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BIOTU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - LVRA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AXS^E: No timezone found, symbol may be delisted
# - ATH^A: No timezone found, symbol may be delisted
# - OXUSW: Period 'max' is invalid, must be one of ['1d', '5d']
# - IPVI: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BWAQ: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CHMI^B: No timezone found, symbol may be delisted
# - PDO: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - DHHCU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - LATGU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - OPP^A: No timezone found, symbol may be delisted
# - IRNT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PTIX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ARQT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MCAER: Period 'max' is invalid, must be one of ['1d', '5d']
# - REXR^C: No timezone found, symbol may be delisted
# - ADSEW: Period 'max' is invalid, must be one of ['1d', '5d']
# - AGNCP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ZI: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CNO^A: No timezone found, symbol may be delisted
# - EEIQ: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NMG: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PLTK: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - DWACW: Period 'max' is invalid, must be one of ['1d', '5d']
# - TLS: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MCAF: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BEAM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - CALT: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PEV: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TGVC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ZING: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - VINC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - WRB^F: No timezone found, symbol may be delisted
# - SABSW: Period 'max' is invalid, must be one of ['1d', '5d']
# - DFH: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - USB^R: No timezone found, symbol may be delisted
# - GATEW: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RILYK: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MGLD: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - DNMR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - EAC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ALOR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - OMGA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AI: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ADOCR: Period 'max' is invalid, must be one of ['1d', '5d']
# - ZTAQU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TYRA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SLAMU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RCRTW: Period 'max' is invalid, must be one of ['1d', '5d']
# - MBTCR: Period 'max' is invalid, must be one of ['1d', '5d']
# - PSA^P: No timezone found, symbol may be delisted
# - GATO: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TALS: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AQNU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - LDHAW: Period 'max' is invalid, must be one of ['1d', '5d']
# - BNR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MITQ: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - NPFD: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - DERM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BODY: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SLDP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PSA^F: No timezone found, symbol may be delisted
# - CFFE: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SLAMW: Period 'max' is invalid, must be one of ['1d', '5d']
# - TNP^E: No timezone found, symbol may be delisted
# - NRAC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ACAC: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AEAE: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ARBE: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BTWNU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MAXN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SQL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - IRRX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BSAQ: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HYZNW: Period 'max' is invalid, must be one of ['1d', '5d']
# - SYF^A: No timezone found, symbol may be delisted
# - MTAL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - DTOCW: Period 'max' is invalid, must be one of ['1d', '5d']
# - CNDB: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SF^C: No timezone found, symbol may be delisted
# - APE: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SATL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - TRON: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - STAR^I: No timezone found, symbol may be delisted
# - ARBGW: Period 'max' is invalid, must be one of ['1d', '5d']
# - SGFY: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SPCMU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - EOSEW: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - LILM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ASCAR: Period 'max' is invalid, must be one of ['1d', '5d']
# - NXLIW: Period 'max' is invalid, must be one of ['1d', '5d']
# - ENTFW: Period 'max' is invalid, must be one of ['1d', '5d']
# - DAVE: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - STIX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AGGR: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - EVLVW: Period 'max' is invalid, must be one of ['1d', '5d']
# - SCUA: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AMST: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - IVR^B: No timezone found, symbol may be delisted
# - PSA^H: No timezone found, symbol may be delisted
# - BGXX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - FRBNU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - PCG^B: No timezone found, symbol may be delisted
# - TKNO: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - BMAQU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AGM^C: No timezone found, symbol may be delisted
# - CMRE^C: No timezone found, symbol may be delisted
# - LYEL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - DATSW: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - ATCO^D: No timezone found, symbol may be delisted
# - BYTS: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - APMI: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HCP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - EVAX: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SKYAU: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AMWL: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - MOLN: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - HYMCW: Period 'max' is invalid, must be one of ['1d', '5d']
# - SLG^I: No timezone found, symbol may be delisted
# - LTH: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - AFGD: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - VNO^N: No timezone found, symbol may be delisted
# - CNM: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - OTRKP: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - IFBD: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - SG: Data doesn't exist for startDate = 1577941200, endDate = 1578027600
# - RELY: Data doesn't exist for startDate = 1577941200, endDate = 1578027600

# %%
end_price.transpose().to_csv('end_price.csv')

# %%
# The historical price data will be loaded from locally stored csv files for convenience.
start_price = pd.read_csv('start_price.csv', names=['Metric','Symbol','Price at 04-Jan-2010'], header=0, keep_default_na=False,
                           na_values = ['', '#N/A', '#N/A N/A', '#NA', '-1.#IND', '-1.#QNAN', 
                                      '-NaN', '-nan', '1.#IND', '1.#QNAN', '<NA>', 'N/A', 
                                      'NULL', 'NaN', 'n/a','nan', 'null'])
end_price = pd.read_csv('end_price.csv', names=['Metric','Symbol','Price at 02-Jan-2020'], header=0, keep_default_na=False,
                           na_values = ['', '#N/A', '#N/A N/A', '#NA', '-1.#IND', '-1.#QNAN', 
                                      '-NaN', '-nan', '1.#IND', '1.#QNAN', '<NA>', 'N/A', 
                                      'NULL', 'NaN', 'n/a','nan', 'null'])

# %%
start_price
# Out:
#           Metric Symbol  Price at 04-Jan-2010
# 0      Adj Close      A             20.434929
# 1      Adj Close     AA             36.938271
# 2      Adj Close    AAC                   NaN
# 3      Adj Close   AACG              0.047792
# 4      Adj Close   AACI                   NaN
# ...          ...    ...                   ...
# 46951     Volume   ZVSA                   NaN
# 46952     Volume    ZWS                   NaN
# 46953     Volume   ZYME                   NaN
# 46954     Volume   ZYNE                   NaN
# 46955     Volume   ZYXI          16500.000000
#
# [46956 rows x 3 columns]

# %%
end_price
# Out:
#           Metric Symbol  Price at 02-Jan-2020
# 0      Adj Close      A             84.799675
# 1      Adj Close     AA             21.373323
# 2      Adj Close    AAC                   NaN
# 3      Adj Close   AACG              1.350000
# 4      Adj Close   AACI                   NaN
# ...          ...    ...                   ...
# 46951     Volume   ZVSA                   NaN
# 46952     Volume    ZWS         809900.000000
# 46953     Volume   ZYME         301100.000000
# 46954     Volume   ZYNE         656100.000000
# 46955     Volume   ZYXI         139040.000000
#
# [46956 rows x 3 columns]

# %%
start_price['Metric'].unique()
# Out:
# array(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'],
#       dtype=object)

# %%
end_price['Metric'].unique()
# Out:
# array(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'],
#       dtype=object)

# %% [markdown]
# Adjusted close price will be used as it is a more accurate measure of stock returns as it accounts for corporate actions such as stock splits, dividends and new stock offerings.

# %%
start_price = start_price[start_price['Metric']=='Adj Close'].drop('Metric', axis=1)
end_price = end_price[end_price['Metric']=='Adj Close'].drop('Metric', axis=1)

# %%
start_price
# Out:
#      Symbol  Price at 04-Jan-2010
# 0         A             20.434929
# 1        AA             36.938271
# 2       AAC                   NaN
# 3      AACG              0.047792
# 4      AACI                   NaN
# ...     ...                   ...
# 7821   ZVSA                   NaN
# 7822    ZWS                   NaN
# 7823   ZYME                   NaN
# 7824   ZYNE                   NaN
# 7825   ZYXI              0.481577
#
# [7826 rows x 2 columns]

# %%
end_price
# Out:
#      Symbol  Price at 02-Jan-2020
# 0         A             84.799675
# 1        AA             21.373323
# 2       AAC                   NaN
# 3      AACG              1.350000
# 4      AACI                   NaN
# ...     ...                   ...
# 7821   ZVSA                   NaN
# 7822    ZWS             32.840000
# 7823   ZYME             47.590000
# 7824   ZYNE              5.880000
# 7825   ZYXI              7.200000
#
# [7826 rows x 2 columns]

# %%
returns = pd.merge(left=start_price, right=end_price, on='Symbol').dropna()

# %%
returns
# Out:
#      Symbol  Price at 04-Jan-2010  Price at 02-Jan-2020
# 0         A             20.434929             84.799675
# 1        AA             36.938271             21.373323
# 3      AACG              0.047792              1.350000
# 7      AAIC              3.799236              5.540000
# 11      AAL              4.496876             28.982893
# ...     ...                   ...                   ...
# 7803   ZIVO              0.280000              0.160000
# 7807    ZNH             13.289250             35.099998
# 7816    ZTR              3.777640              9.547862
# 7818   ZUMZ             12.360000             34.090000
# 7825   ZYXI              0.481577              7.200000
#
# [2952 rows x 3 columns]

# %%
# To create our learning label for machine learning.
returns['Effective annual return'] = (returns['Price at 02-Jan-2020']/returns['Price at 04-Jan-2010'])**(1/10)-1

# %%
returns
# Out:
#      Symbol  Price at 04-Jan-2010  Price at 02-Jan-2020  \
# 0         A             20.434929             84.799675
# 1        AA             36.938271             21.373323
# 3      AACG              0.047792              1.350000
# 7      AAIC              3.799236              5.540000
# 11      AAL              4.496876             28.982893
# ...     ...                   ...                   ...
# 7803   ZIVO              0.280000              0.160000
# 7807    ZNH             13.289250             35.099998
# 7816    ZTR              3.777640              9.547862
# 7818   ZUMZ             12.360000             34.090000
# 7825   ZYXI              0.481577              7.200000
#
#       Effective annual return
# 0                    0.152928
# 1                   -0.053241
# 3                    0.396683
# 7                    0.038440
# 11                   0.204823
# ...                       ...
# 7803                -0.054425
# 7807                 0.101998
# 7816                 0.097156
# 7818                 0.106779
# 7825                 0.310589
#
# [2952 rows x 4 columns]

# %%
stockinfo = pd.merge(left=screener, right=returns, on='Symbol')

# %%
stockinfo
# Out:
#      Symbol                                               Name Last Sale  \
# 0         A             Agilent Technologies Inc. Common Stock   $151.67
# 1        AA                    Alcoa Corporation Common Stock     $45.13
# 2      AACG   ATA Creativity Global American Depositary Shares     $1.27
# 3      AAIC      Arlington Asset Investment Corp Class A (new)     $2.96
# 4       AAL          American Airlines Group Inc. Common Stock    $13.59
# ...     ...                                                ...       ...
# 2947   ZIVO                  Zivo Bioscience Inc. Common Stock     $2.49
# 2948    ZNH  China Southern Airlines Company Limited Common...    $35.21
# 2949    ZTR                      Virtus Total Return Fund Inc.     $6.70
# 2950   ZUMZ                           Zumiez Inc. Common Stock   $22.575
# 2951   ZYXI                            Zynex Inc. Common Stock    $14.11
#
#       Net Change % Change    Market Cap        Country  IPO Year    Volume  \
# 0          1.630   1.086%  4.490525e+10  United States    1999.0   1247420
# 1          0.550   1.234%  7.985174e+09            NaN    2016.0   3523420
# 2          0.010   0.794%  3.984869e+07          China    2008.0      1350
# 3          0.010   0.339%  8.396537e+07  United States       NaN     26879
# 4          0.850   6.672%  8.832153e+09  United States       NaN  34359051
# ...          ...      ...           ...            ...       ...       ...
# 2947       0.000    0.00%  2.345495e+07  United States       NaN      2633
# 2948       1.390    4.11%  1.276073e+10          China    1997.0     15398
# 2949       0.050   0.752%  3.225677e+08  United States    1988.0    243246
# 2950       0.565   2.567%  4.400039e+08  United States    2005.0    428184
# 2951       0.230   1.657%  5.432350e+08  United States       NaN     99851
#
#                       Sector                                    Industry  \
# 0                Industrials                         Electrical Products
# 1                Industrials                          Metal Fabrications
# 2     Consumer Discretionary              Service to the Health Industry
# 3                Real Estate               Real Estate Investment Trusts
# 4     Consumer Discretionary               Air Freight/Delivery Services
# ...                      ...                                         ...
# 2947             Health Care  Biotechnology: Pharmaceutical Preparations
# 2948  Consumer Discretionary               Air Freight/Delivery Services
# 2949                 Finance                         Investment Managers
# 2950                     NaN                                         NaN
# 2951             Health Care                       Other Pharmaceuticals
#
#       Price at 04-Jan-2010  Price at 02-Jan-2020  Effective annual return
# 0                20.434929             84.799675                 0.152928
# 1                36.938271             21.373323                -0.053241
# 2                 0.047792              1.350000                 0.396683
# 3                 3.799236              5.540000                 0.038440
# 4                 4.496876             28.982893                 0.204823
# ...                    ...                   ...                      ...
# 2947              0.280000              0.160000                -0.054425
# 2948             13.289250             35.099998                 0.101998
# 2949              3.777640              9.547862                 0.097156
# 2950             12.360000             34.090000                 0.106779
# 2951              0.481577              7.200000                 0.310589
#
# [2952 rows x 14 columns]

# %%
stockinfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2952 entries, 0 to 2951
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Symbol                   2952 non-null   object
#  1   Name                     2952 non-null   object
#  2   Last Sale                2952 non-null   object
#  3   Net Change               2952 non-null   float64
#  4   % Change                 2952 non-null   object
#  5   Market Cap               2952 non-null   float64
#  6   Country                  2914 non-null   object
#  7   IPO Year                 1127 non-null   float64
#  8   Volume                   2952 non-null   int64
#  9   Sector                   2778 non-null   object
#  10  Industry                 2778 non-null   object
#  11  Price at 04-Jan-2010     2952 non-null   float64
#  12  Price at 02-Jan-2020     2952 non-null   float64
#  13  Effective annual return  2950 non-null   float64
# dtypes: float64(6), int64(1), object(7)
# memory usage: 345.9+ KB

# %%
stockinfo[stockinfo['Effective annual return'].isnull()]
# Out:
#      Symbol                                              Name Last Sale  \
# 865     ELA                   Envela Corporation Common Stock     $5.22
# 1426   ITRN  Ituran Location and Control Ltd. Ordinary Shares    $21.00
#
#       Net Change % Change   Market Cap        Country  IPO Year  Volume  \
# 865        -0.04   -0.76%  140545269.0  United States       NaN   39409
# 1426       -0.20  -0.943%  425611809.0         Israel    2005.0   14127
#
#                       Sector               Industry  Price at 04-Jan-2010  \
# 865   Consumer Discretionary   Consumer Specialties             -0.000002
# 1426              Technology  Electronic Components             -0.417380
#
#       Price at 02-Jan-2020  Effective annual return
# 865               1.380000                      NaN
# 1426             24.200232                      NaN

# %%
# To drop the two stocks with negative adjusted close price as at 04-Jan-2010.
stockinfo = stockinfo[stockinfo['Effective annual return'].notna()]

# %%
stockinfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2950 entries, 0 to 2951
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Symbol                   2950 non-null   object
#  1   Name                     2950 non-null   object
#  2   Last Sale                2950 non-null   object
#  3   Net Change               2950 non-null   float64
#  4   % Change                 2950 non-null   object
#  5   Market Cap               2950 non-null   float64
#  6   Country                  2912 non-null   object
#  7   IPO Year                 1126 non-null   float64
#  8   Volume                   2950 non-null   int64
#  9   Sector                   2776 non-null   object
#  10  Industry                 2776 non-null   object
#  11  Price at 04-Jan-2010     2950 non-null   float64
#  12  Price at 02-Jan-2020     2950 non-null   float64
#  13  Effective annual return  2950 non-null   float64
# dtypes: float64(6), int64(1), object(7)
# memory usage: 345.7+ KB

# %%
stockinfo['Country'].nunique()
# Out:
# 46

# %%
stockinfo['Industry'].nunique()
# Out:
# 148

# %%
stockinfo['Sector'].nunique()
# Out:
# 12

# %%
stockinfo['Sector'].value_counts()
# Out:
# Finance                   790
# Consumer Discretionary    518
# Health Care               342
# Industrials               308
# Technology                298
# Real Estate               125
# Energy                    107
# Utilities                 107
# Consumer Staples           80
# Telecommunications         48
# Basic Materials            37
# Miscellaneous              16
# Name: Sector, dtype: int64

# %% [markdown]
# For the machine learning models, only features from Jan-2010 will be used to predict the stock returns (effective annual returns). Therefore, columns 'Last Sale', 'Net Change', '% Change', 'Market Cap' and 'Volume' are to be removed as they were taken from the NASDAQ Stock Screener on 05Jan2023 7am EST. <br> Column 'Industry' will be dropped as there are too many unique values and furthermore, column 'Sector' will be retained which captures similar information, though not as granular.<br> Stock prices will be dropped as they were used to create the effective annual returns learning label.

# %%
stockinfo = stockinfo.drop(['Last Sale','Net Change','% Change','Market Cap','Volume','Industry','Price at 04-Jan-2010','Price at 02-Jan-2020'], axis=1)

# %%
stockinfo
# Out:
#      Symbol                                               Name        Country  \
# 0         A             Agilent Technologies Inc. Common Stock  United States
# 1        AA                    Alcoa Corporation Common Stock             NaN
# 2      AACG   ATA Creativity Global American Depositary Shares          China
# 3      AAIC      Arlington Asset Investment Corp Class A (new)  United States
# 4       AAL          American Airlines Group Inc. Common Stock  United States
# ...     ...                                                ...            ...
# 2947   ZIVO                  Zivo Bioscience Inc. Common Stock  United States
# 2948    ZNH  China Southern Airlines Company Limited Common...          China
# 2949    ZTR                      Virtus Total Return Fund Inc.  United States
# 2950   ZUMZ                           Zumiez Inc. Common Stock  United States
# 2951   ZYXI                            Zynex Inc. Common Stock  United States
#
#       IPO Year                  Sector  Effective annual return
# 0       1999.0             Industrials                 0.152928
# 1       2016.0             Industrials                -0.053241
# 2       2008.0  Consumer Discretionary                 0.396683
# 3          NaN             Real Estate                 0.038440
# 4          NaN  Consumer Discretionary                 0.204823
# ...        ...                     ...                      ...
# 2947       NaN             Health Care                -0.054425
# 2948    1997.0  Consumer Discretionary                 0.101998
# 2949    1988.0                 Finance                 0.097156
# 2950    2005.0                     NaN                 0.106779
# 2951       NaN             Health Care                 0.310589
#
# [2950 rows x 6 columns]

# %%
stockinfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2950 entries, 0 to 2951
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Symbol                   2950 non-null   object
#  1   Name                     2950 non-null   object
#  2   Country                  2912 non-null   object
#  3   IPO Year                 1126 non-null   float64
#  4   Sector                   2776 non-null   object
#  5   Effective annual return  2950 non-null   float64
# dtypes: float64(2), object(4)
# memory usage: 161.3+ KB

# %%
# To faciliate downloading of feature data from Capital IQ, we will download longName from yahooquery for the stocks. The names downloaded from NASDAQ stock screener include descriptions like 'Common Stock'.
tickers = stockinfo['Symbol'].tolist()

# %%
from yahooquery import Ticker

tickernames = pd.DataFrame.from_dict(Ticker(tickers).price).loc['longName']

# %%
tickernames
# Out:
# A                    Agilent Technologies, Inc.
# AA                            Alcoa Corporation
# AACG                      ATA Creativity Global
# AAIC           Arlington Asset Investment Corp.
# AAL                American Airlines Group Inc.
#                          ...
# ZIVO                      ZIVO Bioscience, Inc.
# ZNH     China Southern Airlines Company Limited
# ZTR               Virtus Total Return Fund Inc.
# ZUMZ                                Zumiez Inc.
# ZYXI                                Zynex, Inc.
# Name: longName, Length: 2950, dtype: object

# %%
stockinfo = tickernames.reset_index().rename(columns={'index':'Symbol'}).merge(stockinfo, on='Symbol')

# %%
stockinfo
# Out:
#      Symbol                                 longName  \
# 0         A               Agilent Technologies, Inc.
# 1        AA                        Alcoa Corporation
# 2      AACG                    ATA Creativity Global
# 3      AAIC         Arlington Asset Investment Corp.
# 4       AAL             American Airlines Group Inc.
# ...     ...                                      ...
# 2945   ZIVO                    ZIVO Bioscience, Inc.
# 2946    ZNH  China Southern Airlines Company Limited
# 2947    ZTR            Virtus Total Return Fund Inc.
# 2948   ZUMZ                              Zumiez Inc.
# 2949   ZYXI                              Zynex, Inc.
#
#                                                    Name        Country  \
# 0                Agilent Technologies Inc. Common Stock  United States
# 1                       Alcoa Corporation Common Stock             NaN
# 2      ATA Creativity Global American Depositary Shares          China
# 3         Arlington Asset Investment Corp Class A (new)  United States
# 4             American Airlines Group Inc. Common Stock  United States
# ...                                                 ...            ...
# 2945                  Zivo Bioscience Inc. Common Stock  United States
# 2946  China Southern Airlines Company Limited Common...          China
# 2947                      Virtus Total Return Fund Inc.  United States
# 2948                           Zumiez Inc. Common Stock  United States
# 2949                            Zynex Inc. Common Stock  United States
#
#       IPO Year                  Sector  Effective annual return
# 0       1999.0             Industrials                 0.152928
# 1       2016.0             Industrials                -0.053241
# 2       2008.0  Consumer Discretionary                 0.396683
# 3          NaN             Real Estate                 0.038440
# 4          NaN  Consumer Discretionary                 0.204823
# ...        ...                     ...                      ...
# 2945       NaN             Health Care                -0.054425
# 2946    1997.0  Consumer Discretionary                 0.101998
# 2947    1988.0                 Finance                 0.097156
# 2948    2005.0                     NaN                 0.106779
# 2949       NaN             Health Care                 0.310589
#
# [2950 rows x 7 columns]

# %%
stockinfo.to_csv('Stockinfo with longName.csv')

# %%
# To import csv file containing fundamental data downloaded from S&P Capital IQ.
stockdata = pd.read_csv('Stock data.csv', encoding='cp1252', index_col=0)

# %%
stockdata.head()
# Out:
#   Symbol                          longName  \
# 0      A        Agilent Technologies, Inc.
# 1     AA                 Alcoa Corporation
# 2   AACG             ATA Creativity Global
# 3   AAIC  Arlington Asset Investment Corp.
# 4    AAL      American Airlines Group Inc.
#
#                                                Name        Country  IPO Year  \
# 0            Agilent Technologies Inc. Common Stock  United States    1999.0
# 1                   Alcoa Corporation Common Stock             NaN    2016.0
# 2  ATA Creativity Global American Depositary Shares          China    2008.0
# 3     Arlington Asset Investment Corp Class A (new)  United States       NaN
# 4         American Airlines Group Inc. Common Stock  United States       NaN
#
#                    Sector  Effective annual return       CIQ ID  \
# 0             Industrials                 0.152928     IQ154924
# 1             Industrials                -0.053241  IQ369991357
# 2  Consumer Discretionary                 0.396683   IQ39920439
# 3             Real Estate                 0.038440      IQ20323
# 4  Consumer Discretionary                 0.204823     IQ168569
#
#           Ticker      Country.1  ... IQ_CASH_ST_INVEST      IQ_NPPE     IQ_GW  \
# 0         NYSE:A  United States  ...        2493.00000    845.00000  655.0000
# 1        NYSE:AA  United States  ...           0.00000      0.00000    0.0000
# 2  NasdaqGM:AACG          China  ...          45.43238      3.07086    3.4272
# 3      NYSE:AAIC  United States  ...          10.12300      0.00000    0.0000
# 4   NasdaqGS:AAL  United States  ...        4399.00000  14837.00000    0.0000
#
#         IQ_RE      IQ_TBV IQ_NET_DEBT IQ_CONTINGENT_LIABILITIES IQ_CASH_OPER  \
# 0  2760.00000  1684.00000   412.00000                       0.0    408.00000
# 1     0.00000     0.00000     0.00000                       0.0      0.00000
# 2   -13.47624    48.40566   -45.43238                       0.0      4.61462
# 3 -1364.47600   150.01300   133.56400                       0.0    -77.61100
# 4 -5136.00000 -4477.00000  7298.00000                       0.0    930.00000
#
#   IQ_CASH_INVEST IQ_NET_CHANGE
# 0      -14.00000    1074.00000
# 1        0.00000       0.00000
# 2       -5.12896      -3.17418
# 3      753.33100    -244.53000
# 4    -2723.00000     -38.00000
#
# [5 rows x 41 columns]

# %%
stockdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2950 entries, 0 to 2949
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Symbol                          2950 non-null   object
#  1   longName                        2950 non-null   object
#  2   Name                            2950 non-null   object
#  3   Country                         2912 non-null   object
#  4   IPO Year                        1126 non-null   float64
#  5   Sector                          2776 non-null   object
#  6   Effective annual return         2950 non-null   float64
#  7   CIQ ID                          2950 non-null   object
#  8   Ticker                          2840 non-null   object
#  9   Country.1                       2950 non-null   object
#  10  Industry                        2945 non-null   object
#  11  Short Business Description      2941 non-null   object
#  12  IQ_TOTAL_REV                    2950 non-null   float64
#  13  IQ_RETURN_ASSETS                2950 non-null   float64
#  14  IQ_RETURN_EQUITY                2950 non-null   object
#  15  IQ_GROSS_MARGIN                 2950 non-null   object
#  16  IQ_EBITDA_MARGIN                2663 non-null   object
#  17  IQ_NI_MARGIN                    2950 non-null   object
#  18  IQ_AUDITOR_OPINION              2950 non-null   object
#  19  IQ_ASSET_TURNS                  2950 non-null   object
#  20  IQ_CURRENT_RATIO                2950 non-null   float64
#  21  IQ_DAYS_SALES_OUT               2950 non-null   object
#  22  IQ_DAYS_INVENTORY_OUT           2950 non-null   object
#  23  IQ_DAYS_PAYABLE_OUT             2950 non-null   object
#  24  IQ_TOTAL_DEBT_EQUITY            2950 non-null   object
#  25  IQ_TOTAL_REV_1YR_ANN_GROWTH     2950 non-null   object
#  26  IQ_NI_1YR_ANN_GROWTH            2950 non-null   object
#  27  IQ_CFO_1YR_ANN_GROWTH           2950 non-null   object
#  28  IQ_TOTAL_ASSETS_1YR_ANN_GROWTH  2950 non-null   float64
#  29  IQ_EBITDA                       2663 non-null   float64
#  30  IQ_PAYOUT_RATIO                 2949 non-null   object
#  31  IQ_CASH_ST_INVEST               2949 non-null   float64
#  32  IQ_NPPE                         2949 non-null   float64
#  33  IQ_GW                           2949 non-null   float64
#  34  IQ_RE                           2949 non-null   float64
#  35  IQ_TBV                          2949 non-null   float64
#  36  IQ_NET_DEBT                     2949 non-null   float64
#  37  IQ_CONTINGENT_LIABILITIES       2949 non-null   float64
#  38  IQ_CASH_OPER                    2949 non-null   float64
#  39  IQ_CASH_INVEST                  2949 non-null   float64
#  40  IQ_NET_CHANGE                   2949 non-null   float64
# dtypes: float64(17), object(24)
# memory usage: 968.0+ KB

# %% [markdown]
# Fundamental data were downloaded from Capital IQ to be used as features to predict effective annual return. These fundamental data are for financial year ending 2009 updated as at 01-Apr-2023 (date of retrieval of data), and are in USD (for monetary figures - using historical exchange rates) or % (for ratios). <br> <br>
# The fundamental data (29 metrics in total) obtained from Capital IQ have the following definitions: <br>
# **IQ_TOTAL_REV**: Revenues + Other Revenues, Total	<br>
# **IQ_RETURN_ASSETS**: EBIT * (1-0.375) / Average Total Assets	<br>
# **IQ_RETURN_EQUITY**:	Earnings from Continuing Operations / Average Total Equity<br>
# **IQ_GROSS_MARGIN**: Gross Profit / Total Revenues <br>
# **IQ_EBITDA_MARGIN**: EBITDA / Total Revenues	<br>
# **IQ_NI_MARGIN**: Net Income / Total Revenues	<br>
# **IQ_AUDITOR_OPINION**: Auditor Opinion	<br>
# **IQ_ASSET_TURNS**: Total Revenues / Average Total Assets	<br>
# **IQ_CURRENT_RATIO**: Total Current Assets / Total Current Liabilities	<br>
# **IQ_DAYS_SALES_OUT**: Average Accounts Receivable / Revenues * 360	<br>
# **IQ_DAYS_INVENTORY_OUT**: Average Inventory / Cost of Goods Sold * 360	<br>
# **IQ_DAYS_PAYABLE_OUT**: Average Accounts Payable / (Cost of Goods Sold - Beginning Inventory + Ending Inventory) * Number of Days in the Period	<br>
# **IQ_TOTAL_DEBT_EQUITY**: Total Debt / Total Equity	<br>
# **IQ_TOTAL_REV_1YR_ANN_GROWTH**: Total Revenues (t) / Total Revenues (t-1) - 1	<br>
# **IQ_NI_1YR_ANN_GROWTH**: Net Income (t) / Net Income (t-1) -1	<br>
# **IQ_CFO_1YR_ANN_GROWTH**: Cash from Operations (t) / Cash from Operations (t-1) -1	<br>
# **IQ_TOTAL_ASSETS_1YR_ANN_GROWTH**: Total Assets (t) / Total Assets (t-1) -1	<br>
# **IQ_EBITDA**: EBITDA	<br>
# **IQ_PAYOUT_RATIO**: (Common Dividends Paid + Preferred Dividends Paid) / Net Income	<br>
# **IQ_CASH_ST_INVEST**: Cash and Equivalents + Short Term Investments + Trading Asset Securities	<br>
# **IQ_NPPE**: Gross Property Plant and Equipment + Accumulated Depreciation	<br>
# **IQ_GW**: Goodwill	<br>
# **IQ_RE**: Retained Earnings	<br>
# **IQ_TBV**: Book Value of Common Equity - Goodwill = Other Intangibles - Fin. Div. Goodwill - Fin. Div. Other Intangibles	<br>
# **IQ_NET_DEBT**: Total Debt - Total Cash and Short Term Investments - Long Term Marketable Securities	<br>
# **IQ_CONTINGENT_LIABILITIES**: Contingent Liabilites <br>
# **IQ_CASH_OPER**: Cash from Operations <br>
# **IQ_CASH_INVEST**: Cash from Investing <br>
# **IQ_NET_CHANGE**: Cash from Operations + Cash from Investing + Cash from Financing + Foreign Exchange Rate Adjustments + Misc. Cash Flow Adjustments
